# %% [markdown]
# # Running tensorflow on Trade data
#
# ## Reading data from database

# %%
import codes.handlers as hd

rides = hd.ReadPanda('trade-graph', (13,))
rides[:24*10].plot(x='DateTimeEn', y='ClosePrice')
# Out:
# <AxesSubplot:xlabel='DateTimeEn'>

# %%
import codes.trade as trade

trade.read_trade(300, 10, 150000)
# Out:
# Reading data: 1157
# Reading data: 2316
# Reading data: 3424
# Reading data: 4602
# Reading data: 5645
# Reading data: 6890
# Reading data: 8125
# Reading data: 9273
# Reading data: 10525
# Reading data: 11800
# Reading data: 13044
# Reading data: 14293
# Reading data: 15474
# Reading data: 16749
# Reading data: 18050
# Reading data: 19231
# Reading data: 20462
# Reading data: 21731
# Reading data: 22747
# Reading data: 23908
# Reading data: 24945
# Reading data: 26215
# Reading data: 27439
# Reading data: 28653
# Reading data: 29896
# Reading data: 31155
# Reading data: 32409
# Reading data: 33673
# Reading data: 34964
# Reading data: 36139
# Reading data: 37391
# Reading data: 38495
# Reading data: 39491
# Reading data: 40764
# Reading data: 42017
# Reading data: 43207
# Reading data: 44425
# Reading data: 45490
# Reading data: 46691
# Reading data: 47810
# Reading data: 48923
# Reading data: 50114
# Reading data: 51313
# Reading data: 52510
# Reading data: 53747
# Reading data: 54884
# Reading data: 54952
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9094/3763889681.py in <module>
#       1 import codes.trade as trade
#       2
# ----> 3 trade.read_trade(300, 10, 150000)
#
# ~/Developing/Stock Estimation/Jiringi/Python/codes/trade.py in read_trade(input_size, output_size, batch_size, verbose)
#       4 def read_trade(input_size, output_size, batch_size, verbose = 1):
#       5     loader = TradeReader(input_size, output_size, batch_size, verbose)
# ----> 6     loader.ReadData()
#       7
#       8 class TradeReader:
#
# ~/Developing/Stock Estimation/Jiringi/Python/codes/trade.py in ReadData(self)
#      20
#      21     def ReadData(self):
# ---> 22         hd.SqlQueryExecute('trade-selection', (self.BUFFER_SIZE, ), self.__data_handler)
#      23
#      24     def __data_handler(self, cursor):
#
# ~/Developing/Stock Estimation/Jiringi/Python/codes/handlers.py in SqlQueryExecute(file, parameters, job)
#      19         with connection.cursor() as cursor:
#      20             cursor.execute(query, parameters)
# ---> 21             job(cursor)
#      22
#      23 def GetConnection():
#
# ~/Developing/Stock Estimation/Jiringi/Python/codes/trade.py in __data_handler(self, cursor)
#      29             print("Reading data: ...", end='')
#      30         dur = time.time()
# ---> 31         for row in cursor:
#      32             if instrument != row[1]:
#      33                 instrument = row[1]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Creating the model

# %%
import tensorflow.keras as keras

model = keras.models.Sequential(name='logits')
model.add(keras.Input(shape=x_training.shape[1:]))

model.add(keras.layers.Conv2D(3, (1, 5), strides=(1, 1), activation='gelu'))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Conv2D(6, (1, 5), strides=(1, 1), activation='gelu'))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Conv2D(9, (1, 5), strides=(1, 1), activation='gelu'))
model.add(keras.layers.Dropout(0.2))

model.add(keras.layers.Flatten())

model.add(keras.layers.Dense(60, activation="gelu"))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(y_training.shape[1:], activation="sigmoid"))

model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics=['accuracy'])

model.summary()

# %% [markdown]
# ## Running tensorflow

# %%
from keras.callbacks import ModelCheckpoint

check_point_path = 'mnist.mlp.gelu.b2.model.best.hdf5'

# train the model
checkpointer = ModelCheckpoint(filepath=check_point_path, 
                               verbose=1, save_best_only=True)

x_training = np.load('trade-all-x.npy')
y_training = np.load('trade-all-y.npy')

# %%
hist = model.fit(x_training, y_training, batch_size=512, epochs=3,
          validation_split=0.2, callbacks=[checkpointer],
          verbose=0, shuffle=True)
