# %%
from codes.handlers import Handlers
from codes.trade import TradeReader

hd = Handlers('solution_1')

loader = TradeReader(hd, verbose=4)
loader.ReadData(ignore_existing=False)
# Out:
# 2022-08-03 14:52:13.035279: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-03 14:52:13.035308: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Options:  {'Input Size': 120, 'Output Size': [3, 4], 'Batch Count': 5, 'Factor': 100}
# Reading data: 99.97% = (900641, 931, 44975, 931, -0.05217391304347826)	files (4) have been saved: x=(179832, 120, 1, 1), y=(179832, 3))))))
# Reading finished in 309.27 sec and 5 files	files (5) have been saved: x=(144464, 120, 1, 1), y=(144464, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from codes.handlers import Handlers

hd = Handlers('solution_1')
plt.rcParams['figure.figsize'] = [20, 5]

x_testing, y_testing = hd.LoadTestData(1)

data = np.average(y_testing, axis=1)
data = np.reshape(data, data.shape[0])
print("data.shape:", data.shape)

plt.plot(data, label='Training loss')
plt.legend()
_ = plt.ylim()
# Out:
# Loading finished, shape = (144464, 120, 1, 1)
# Loading finished, shape = (144464, 3)
# testing.shapes: x(144464, 120, 1, 1), y(144464, 3)
# data.shape: (144464,)

# %%
from codes.handlers import Handlers

hd = Handlers('solution_1')
rides = hd.ReadPanda('query', (120, 100))
print("Records:", rides.shape)
if rides.size > 0:
    rides.plot(title='Intrument Types', x='Ranking', y='CloseIncreasing', figsize=(20, 5))
# Out:
# Records: (910378, 5)
