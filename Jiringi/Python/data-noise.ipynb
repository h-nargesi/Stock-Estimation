# %% [markdown]
# # Examine data noises

# %%
import codes.handlers as hd

rides = hd.ReadPanda('trade-graph', ("19835, 19823, 19843", 10, 0, 450,))
# 'OpenPrice', 'LowPrice', 'HighPrice', 
rides = rides.pivot(index='DateTimeEn', columns='Instrument', values=['ClosePrice'])
# print(rides.columns)
rides.plot(title='Trade', kind='line', figsize=(20, 5))
# Out:
# <AxesSubplot:title={'center':'Trade'}, xlabel='DateTimeEn'>

# %%
import codes.handlers as hd

rides = hd.ReadPanda('density-graph', ("19835, 19823, 19843", 10, 0, 450,))
rides = rides.pivot(index='GroupingValue', columns='InstrumentID', values=['Density'])
# print(rides.columns)
rides.plot(title='Density', kind='line', figsize=(20, 5))
# Out:
# <AxesSubplot:title={'center':'Density'}, xlabel='GroupingValue'>

# %%
import codes.handlers as hd

rides = hd.ReadPanda('instruments-types')
rides.plot(title='Intrument Types', x='TitleEn', y='RowCounts', kind='bar', figsize=(20, 5))
# Out:
# <AxesSubplot:title={'center':'Intrument Types'}, xlabel='TitleEn'>

# %%
import codes.handlers as hd

rides = hd.ReadPanda('trade-graph', ("17321, 17322", 10, 0, 450000,))
# 'OpenPrice', 'LowPrice', 'HighPrice', 
rides = rides.pivot(index='DateTimeEn', columns='Instrument', values=['ClosePrice'])
# print(rides.columns)
rides.plot(title='Trade', kind='line', figsize=(20, 5))
# Out:
# <AxesSubplot:title={'center':'Trade'}, xlabel='DateTimeEn'>
